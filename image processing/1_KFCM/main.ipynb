# %%
# import os

# search_dir = '/content/drive/Othercomputers/My Laptop/python/image processing'
# all_pgms = []

# if not os.path.exists(search_dir):
#     print(f"Error: Directory '{search_dir}' does not exist.")
# elif not os.listdir(search_dir):
#     print(f"Directory '{search_dir}' is empty.")
# else:
#     print(f"Searching for .pgm and .ppm files in '{search_dir}':")
#     found_files = False
#     for root, dirs, files in os.walk(search_dir):
#         for ffile in files:
#             if ffile.endswith(('.pgm', '.ppm')):
#                 all_pgms.append(os.path.join(root, ffile))
#                 found_files = True
#     print(f"{len(all_pgms)} file(s) found")
#     if not found_files:
#         print("No .pgm or .ppm files found.")

# %%
# import cv2 as cv
# from google.colab.patches import cv2_imshow

# for files in all_pgms:
#     img = cv.imread(files)
#     if img is not None:
#         cv2_imshow(img) # Use cv2_imshow from google.colab.patches
#         # cv.waitKey(0) # Not needed with cv2_imshow
#         # cv.destroyAllWindows() # Not needed with cv2_imshow
#     else:
#         raise ValueError(f'Can\'t open {files}')
