# %% [markdown]
# READ.py

# %%
# FOR IMAGE


import cv2 as cv
import numpy as np
img= cv.imread("E:/python/image processing/k_means_clustering/girlOutKMeans.pgm",cv.IMREAD_GRAYSCALE)
if img is not None:
    cv.imshow("Cat", img)
    cv.waitKey(0)
    cv.destroyAllWindows()
else:
    print("Image not found")

# %%
# FOR VIDEO

import cv2 as cv

capture = cv.VideoCapture("Videos/dog.mp4")

while True:
    isTrue,frame = capture.read()
    if isTrue == False:
        break
    cv.imshow('Video',frame)
    if cv.waitKey(20) & 0xFF == ord('d'):
        break
    
capture.release()
cv.destroyAllWindows()

# %%
# SCALING AND RESIZING

import cv2 as cv

def rescale(frame, scale = 0.75):
    width = int(frame.shape[1]*scale)
    height = int(frame.shape[0]*scale)
    return cv.resize(frame,(width,height),interpolation=cv.INTER_AREA)

capture = cv.VideoCapture('videos/dog.mp4')
while True:
    isTrue,Frame = capture.read()
    if isTrue == False:
        cv.waitKey(0)
        print("No more frames found...")
        break
    cv.imshow('Dog',Frame)
    FrameResized = rescale(Frame, scale = 0.65)
    cv.imshow('Dog-Resized',FrameResized)
    if cv.waitKey(100) & 0xFF == ord('\x1b'):
        break
capture.release()
cv.destroyAllWindows()

# %%
import cv2 as cv

while True:
    scale = int(input("Enter the percentage you want your image to be: "))
    if 0<=scale<=100:
        break
    else:
        print("Try Again")

def rescale(frame,scale=0.75):
    height = int(frame.shape[0]*scale)
    width = int(frame.shape[1]*scale)
    return cv.resize(frame,(width,height),interpolation=cv.INTER_AREA)

img = cv.imread('photos/cat_large.jpg')
if img is not None:
    cv.imshow('Cat',img)
    cv.imshow('Cat-Resized',rescale(img,scale=scale/100))
    cv.waitKey(0)
    cv.destroyAllWindows()
# Out:
# Try Again
# Try Again

# %% [markdown]
# DRAWING ON IMAGE
